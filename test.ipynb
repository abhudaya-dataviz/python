# %%
import pandas as pd

# %%
print("print hellow orld")
# Out:
# print hellow orld

# %%
check = pd.Series([1, 2, 3, 4, 5])
print(check)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
print("hellow from ashsish")
# Out:
# hellow from ashsish
